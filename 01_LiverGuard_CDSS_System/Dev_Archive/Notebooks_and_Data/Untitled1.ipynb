# %%
import pandas as pd
import numpy as np
import math
from datetime import datetime, date
from sqlalchemy import create_engine

# DB 연결
engine = create_engine('postgresql://postgres:acorm1234@localhost:5432/postgres')

# 연결 테스트
with engine.connect() as conn:
    print("✅ DB 연결 성공!")
# Out:
# ✅ DB 연결 성공!
